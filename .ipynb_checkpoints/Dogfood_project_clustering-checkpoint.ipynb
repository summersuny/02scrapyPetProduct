# %%
import numpy as np
import pandas as pd
df1 = pd.read_csv('~/Desktop/chewy/chewydogfood_new.csv')
df2 = pd.read_csv('~/Desktop/chewy2/chewycatfood.csv',encoding='latin-1')
df=pd.concat([df1,df2],ignore_index=True)
# Out:
# array([   0,    1,    2, ..., 5020, 5021, 5022])

# %%
print(df.count())
print(df1.count())
print(df2.count())
# Out:
# brand             4278
# category          4278
# ingredient        4244
# name              4278
# page              5023
# price             4276
# rating            4278
# reviews_number    4003
# unit              1814
# dtype: int64
# brand             2182
# category          2182
# ingredient        2166
# name              2182
# page              2878
# price             2180
# rating            2182
# reviews_number    2005
# unit              1004
# dtype: int64
# brand             2096
# category          2096
# ingredient        2078
# name              2096
# page              2145
# price             2096
# rating            2096
# reviews_number    1998
# unit               810
# dtype: int64

# %%
def strip_obj(col):
    return col.str.strip()

df=df.apply(strip_obj, axis=1)  #trim data

# %%
df.head()
# Out:
#                   brand  category  \
# 0  By Taste of the Wild  Dog,Food
# 1            By CANIDAE  Dog,Food
# 2       By Blue Buffalo  Dog,Food
# 3       By Blue Buffalo  Dog,Food
# 4       By Blue Buffalo  Dog,Food
#
#                                           ingredient  \
# 0  Crude Protein,32.0% min,Crude Fat,18.0% min,Cr...
# 1  Crude Protein ,24.0% min,Crude Fat ,14.5% min,...
# 2  Crude Protein,20.0% min,Crude Fat,12.0% min,Cr...
# 3  Crude Protein,28.0% min,Crude Fat,13.0% min,Cr...
# 4  Crude Protein,24.0% min,Crude Fat,14.0% min,Cr...
#
#                                                 name  page   price  \
# 0  Taste of the Wild High Prairie Grain-Free Dry ...   NaN  $48.99
# 1  CANIDAE Life Stages All Life Stages Formula Dr...   NaN  $56.99
# 2  Blue Buffalo Basics Limited Ingredient Grain-F...   NaN  $51.99
# 3  Blue Buffalo Wilderness Rocky Mountain Recipe ...   NaN  $51.99
# 4  Blue Buffalo Freedom Adult Chicken Recipe Grai...   NaN  $47.99
#
#                                rating  reviews_number       unit
# 0  /assets/img/ratings/rating-4_7.png             NaN  30-lb bag
# 1  /assets/img/ratings/rating-4_7.png             NaN  44-lb bag
# 2  /assets/img/ratings/rating-4_7.png             NaN  22-lb bag
# 3  /assets/img/ratings/rating-4_7.png             NaN        NaN
# 4  /assets/img/ratings/rating-4_8.png             NaN  24-lb bag

# %%
df['ingredient'].iloc[5]
# Out:
# 'Crude Protein,32.0% min,Crude Fat,18.0% min,Crude Fiber,4.0% max,Moisture,10.0% max,Zinc,150 mg/kg min,Selenium,0.35 mg/kg min,Vitamin E,150 IU/kg min,Omega 6 Fatty Acids,2.4% min,Omega 3 Fatty Acids,0.4% min,Total Microorganisms,1,000,000 CFU/lb min'

# %%
#dict(map(lambda x: x.strip().rsplit(',', 1), df.iloc[1, 2].split('%')))

# %%
#re.split('min,|max,',df.iloc[1, 2])

# %%
#dict(map(lambda x: x.strip().rsplit(',',1) , re.split('min,|max,',df.iloc[1, 2])))

# %%
from itertools import chain
a=df.ingredient[0]
#re.findall('([a-zA-Z]+\s?[a-zA-Z]+),\d',a)


#find the list of unique ingridient
def glist(x): 
    return [ i for i in re.split(',',x) if (i=='' or i[0].isalpha())\
            and i[0:3]!='Add' and i[0:4]!='Dogs' and i[0:4]!='Feed'\
            and i.upper()[0:4]!='OVER' and i[0:5]!='Small' and i[0:6]!='Medium'\
            and i[0:3]!='Toy' and i.upper()[0:2]!='UP'\
            and i[0:3]!='lbs' and i[0:7]!= 'Puppies' and i[0:4]!= 'Less'\
            and i[0:5]!= 'Large' and i[0:6]!='Highly' and i[0:5]!='Giant'\
            and i.upper()[0:5]!='UNDER' and i.upper()[0:6]!='WEIGHT'\
            and i.upper()[0:10]!='TRANSITION' and i.upper()[0:10]!='MINI ADULT'\
            and i.upper()[0:9]!=r'MG/KG MIN' and i.upper()[0:3]!='DAY'\
            and i.upper()[0:5]!='ADULT' and i.upper()[0:4]!='PLUS' and i.upper()[0:5]!='START'\
            and i.upper()[0:6]!='KITTEN' and i.upper()[0:4]!='KEEP' \
            and i.upper()[0:5]!=r'IU/KG' and i.upper()[0:5]!='FULLY' \
            and i.upper()[0:4]!='FREE' and i.upper()[0:3]!='FOR'\
            and i.upper()[0:4]!='FEED' and i.upper()[0:11]!='EXTRA LARGE'\
            and i.upper()[0:6]!='DURING' and i.upper()[0:4]!='CATS'\
            and i.upper()[0:5]!='ABOVE' and i.upper()[0:3]!='ADD'\
            and i.upper()[0:3]!='MAX' and i.upper()[0:3]!='MIN'\
            and i.upper()[0:3]!=r'N/A' and i.upper()[0:3]!='NAN'\
            and i.upper()[0:8]!='NOT LESS' and i.upper()[0:6]!='SENIOR' and i.upper()[0:2]!=r'X-'
           ]

df.ingredient=df.ingredient.astype(np.str)
from itertools import chain
def chain_list(nested_list):
    return list(chain(*nested_list))

list_ind=chain_list(df.ingredient.map(lambda x: glist(x)))

list_ind=set([x.strip().upper() for x in list_ind])
list_ind=list(list_ind)  #export to csv and create a new tag in new column

# %%
list_ind_csv=['EPA  EICOSAPENTAENOIC ACID    DHA  DOCOSAHEXAENOIC ACID ',
 'L ASCORBYL 2 POLYPHOSPHATE   SOURCE OF VITAMIN C ',
 'L ASCORBYL 2 POLYPHOSPHATE  SOURCE OF VITAMIN C ',
 'TOTAL MICROORGANISMS  LACTOBACILLUS ACIDOPHILUS',
 'ALPHA LINOLENIC ACID  AN OMEGA 3 FATTY ACID ',
 'ALPHA LINOLENIC ACID  OMEGA 3 FATTY ACID ',
 'CHONDROITIN SULFATE  NATURALLY OCCURRING ',
 'MICROORGANISMS  LACTOBACILLUS ACIDOPHILUS',
 'VITAMIN E  DL ASLPHA TOCOPHERYL ACETATE ',
 'APPROXIMATE NUMBER OF 8 OZ CUPS PER DAY',
 'LINOLEIC ACID  AN OMEGA 6 FATTY ACID ',
 'ASCORBIC ACID  SOURCE OF VITAMIN C  ',
 'LINOLEIC ACID   OMEGA 6 FATTY ACIDS ',
 'ASCORBIC ACID  SOURCE OF VITAMIN C ',
 'LINOLEIC ACID  OMEGA 6 FATTY ACID ',
 'GLUCOSAMINE  NATURALLY OCCURRING ',
 'TOTAL LACTIC ACID MICROORGANISMS ',
 'TOTAL LACTIC ACID MICROORGANISMS',
 'ALPHA LINOLENIC ACID  OMEGA 3 ',
 'GESTATING 5 8  ',
 'BIFIDOBACTERIUM THERMOPHILUM',
 'BREEDING MARES AND STALLIONS',
 'CALCIUM TO PHOSPHOROUS RATIO',
 'GESTATING 1 2  ',
 'MANNANOLIGOSACCHARIDES  MOS ',
 'CALCIUM   PHOSPHOROUS RATIO',
 'DOCOSAHEXAENOIC ACID  DHA  ',
 'EICOSAPENTAENOIC ACID  EPA ',
 'EPA  EICOSAPENTAENOIC ACID ',
 'FUCTOOLIGOSACCHARIDES  FOS ',
 'VITAMIN A  RETINYL ACETATE ',
 'VITAMIN D  CHOLECALCIFEROL ',
 'ABSORBIC ACID*  VITAMIN C ',
 'ALPHA LINOLENIC ACID  ALA ',
 'ASCORBIC ACID  VITAMIN C  ',
 'ASCORBIC ACID  VITMAIN C  ',
 'CHONDROITIN SULFATE  MIN  ',
 'DHA  DOCOSAHEXAENOIC ACID ',
 'DHA  DOCOSOHEXAENOIC ACID ',
 'DOCOSAHEXAENOIC ACID  DHA ',
 'DOCOSOHEXAENOIC ACID  DHA ',
 'EICOSAPENTAENOIC ACID  EPA',
 'GLUCOSAMINE HYDROCHLORIDE ',
 'LACTIC ACID MICROORGANISMS',
 'OMEGA 3 FATTY ACIDS  MIN  ',
 'OMEGA 6 FATTY ACIDS  MIN  ',
 'ASCORBIC ACID  VITAMIN C ',
 'ASCORBIC ACIF  VITAMIN C ',
 'ASCROBIC ACID  VITAMIN C ',
 'CALCIUM PHOSPHOROUS RATIO',
 'GLUCOSAMINE HYDROCHLORIDE',
 'LACTOBACILLUS ACIDOPHILUS',
 'MOISTEN   FEED FREQUENTLY',
 'OMEGA 6 FATTY ACIDS TOTAL',
 'ASCORBIC ACID  VITAMIN C',
 'ASCORBIC ACID  VITAMINC ',
 'CALIUM PHOSPHOROUS RATIO',
 'DOCOSOHEXAENOICACID DHA ',
 'LACOBACILUUS ACIDOPHILUS',
 'LINOLENIC ACID  OMEGA 3 ',
 'OMEGA 3  LINOLENIC ACID ',
 'TOTAL BACILLUS ORGANISMS',
 'ENCAPSULATED PROBIOTICS',
 'LINOLEIC ACID  OMEGA 6 ',
 'OMEGA 3 FATTY ACIDS MIN',
 'OMEGA 6  LINOLEIC ACID ',
 'OMEGA 6 FATTY ACIDS MIN',
 'PYRIDOXINE  VITAMIN B6 ',
 'SELENIUM 0 35 MG KG MIN',
 'BIFIDOBACTERIUM LONGUM',
 'FRUCTOOLIGOSACCHARIDES',
 'LINOLENIC ACID OMEGA 3',
 'OMEGA   3 FATTY ACIDS ',
 'OMEGA   6 FATTY ACIDS ',
 'SELENIUM  45 MG KG MIN',
 'EICOSAPENTAENOIC ACID',
 'LINOLEIC ACID OMEGA 6',
 'MANNANOLIGOACCHARIDES',
 'OMEGA  6 FATTY ACIDS ',
 'OMEGA   3 FATTY ACIDS',
 'OMEGA   6 FATTY ACIDS',
 'PRODUCE   SUPPLEMENTS',
 'TOTAL MICRO ORGANISMS',
 'TOTAL MICROORGANISMS ',
 'TOTAL MICROORGANSISMS',
 'ALPHA LINOLENIC ACID',
 'CHONDROITIN SULFATE ',
 'CHONDROITIN SULPHATE',
 'DOCOSAHEXAENOIC ACID',
 'ENTEROCOCCUS FAECIUM',
 'LACTIC ACID BACTERIA',
 'METABOLIZABLE ENERGY',
 'OMEGA 3 FATTY ACIDS ',
 'OMEGA 6 FATTY ACIDS ',
 'TOTAL MICROORGANISMS',
 'ASH  MAX  6 50% MAX',
 'BACILLIUS COAGULANS',
 'BACILLUS COAGULANS ',
 'CALCIUM PHOSPHOROUS',
 'CARBOHYDRATES  NFE ',
 'CHONDROITIN SULFATE',
 'CRUDE PROTEIN  MIN ',
 'FATTY ACIDS OMEGA 3',
 'FATTY ACIDS OMEGA 6',
 'GLUCOSAMINE SULFATE',
 'MAGNESIUM 0 14% MAX',
 'OMEGA 3 FATTY ACIDS',
 'OMEGA 6 FATTY ACIDS',
 'OMEGA 3 FATTY ACID ',
 'ORGANIC INGREDIENTS',
 'BACILLUS COAGULANS',
 'CARBOHYDRATE   NFE',
 'CHODROITIN SULFATE',
 'COSAHEXAENOIC ACID',
 'GLUCOSAMINE  MIN  ',
 'OMEGA 3 FATTY ACID',
 'OMEGA 6 FATTY ACID',
 'BACILLUS SUBTILIS',
 'CRUDE FIBER  MAX ',
 'CRUDE PROTEIN MIN',
 'TAURINE 0 05% MIN',
 'TOTAL ISOFLAVONES',
 'ARACHIDONIC ACID',
 'CARBOHYDRATE NFE',
 'OMEGA3FATTYACIDS',
 'OMEGA6FATTYACIDS',
 'PHOSPHORUS  MIN ',
 'TOTAL OMEGA 3 FA',
 'TOTAL OMEGA 6 FA',
 'CRUDE FAT  MIN ',
 'CRUDE FIBER MAX',
 'ENZYMES  LIPASE',
 'GLUCOSAMINE HCL',
 'MAGNESIUM  MAX ',
 'ABSORBIC ACID ',
 'ASCORBIC ACID ',
 'BETA CAROTENE ',
 'CRUDE MOISTURE',
 'LINEOLEIC ACID',
 'LINOLENIC ACID',
 'MICROORGANISMS',
 'MOISTURE  MAX ',
 'PHOSPHORUS  P ',
 'VITAMIN E MIN ',
 'ALPHA AMYLASE',
 'ASCORBIC ACID',
 'BETA CAROTENE',
 'CA TO P RATIO',
 'CALCIUM  MIN ',
 'CARBOHYDRATES',
 'CRUDE FAT MIN',
 'CRUDE PROTEIN',
 'EVERY 10+ LBS',
 'LINOLEIC ACID',
 'LINOLIEC ACID',
 'MOTHER’S MILK',
 'SELENIUM  SE ',
 'VITAMIN A MIN',
 'VITAMIN E MIN',
'ABSORBIC ACID',
 'BONE CONTENT',
 'CALCIUM  CA ',
 'CARBOHYDRATE',
 'CRUDEPROTEIN',
 'GLUCOSAMINE ',
 'L CARNITINE ',
 'MOISTURE MAX',
 'VITAMIN E 35',
 'ASH CONTENT',
 'CHONDROITIN',
 'CRUDE FIBER',
 'CRUDE FIBRE',
 'GLUCOSAMINE',
 'L CARNITINE',
 'OMEGA 3 DHA',
 'PHOSPHEROUS',
 'PHOSPHOROUS',
 'TAURINE MIN',
 'AD LIBITUM',
 'CRUDEFIBER',
 'FOLIC ACID',
 'I CARNITIE',
 'INULIN FOS',
 'L ARGININE',
 'METHIONINE',
 'ORGAN MEAT',
 'PHOSPHORUS',
 'PHOSPOROUS',
 'PYRIDOXINE',
 'RIBOFLAVIN',
 'TAURINE DM',
 'VITAMIN D3',
 'VITAMINE E',
 'CRUDE ASH',
 'CRUDE FAT',
 'CRUDE OIL',
 'DHA   EPA',
 'EPA   DHA',
 'IRON  FE ',
 'MAGNESIUM',
 'MANGANESE',
 'PHOSPORUS',
 'VITAMIN A',
 'VITAMIN C',
 'VITAMIN D',
 'VITAMIN E',
 'ZINC  ZN ',
 'ARGININE',
 'CAROTENE',
 'CHLORIDE',
 'CRUDEFAT',
 'IRON 225',
 'ASH MAX',
 'AVERAGE',
 'DHA MIN'
]

# %%
list_tag=[
'EPA',
'VITAMIN_C',
'VITAMIN_C',
'MICRO_ORGANISMS',
'OMEGA3',
'OMEGA3',
'CHONDROITIN',
'LACOBACILUUS_ACIDOPHILUS',
'VITAMIN_E',
'DUMMY',
'OMEGA6',
'VITAMIN_C',
'OMEGA6',
'VITAMIN_C',
'OMEGA6',
'GLUCOSAMINE',
'LACTIC_ACID',
'LACTIC_ACID',
'OMEGA3',
'GLUCOSAMINE',
'BIFIDOBACTERIUM',
'DUMMY',
'CALCIUM',
'GLUCOSAMINE',
'MOS',
'CALCIUM',
'DHA',
'EPA',
'EPA',
'FOS',
'VITAMIN_A',
'VITAMIN_D',
'VITAMIN_C',
'OMEGA3',
'VITAMIN_C',
'VITAMIN_C',
'CHONDROITIN',
'DHA',
'DHA',
'DHA',
'DHA',
'EPA',
'GLUCOSAMINE',
'LACTIC_ACID',
'OMEGA3',
'OMEGA6',
'VITAMIN_C',
'VITAMIN_C',
'VITAMIN_C',
'CALCIUM',
'GLUCOSAMINE',
'LACOBACILUUS_ACIDOPHILUS',
'DUMMY',
'OMEGA6',
'VITAMIN_C',
'VITAMIN_C',
'CALCIUM',
'DHA',
'LACOBACILUUS_ACIDOPHILUS',
'OMEGA3',
'OMEGA3',
'BACILLIUS',
'ENCAPSULATED_PROBIOTICS',
'OMEGA6',
'OMEGA3',
'OMEGA6',
'OMEGA6',
'VITAMIN_B6',
'SELENIUM',
'BIFIDOBACTERIUM',
'FOS',
'OMEGA3',
'OMEGA3',
'OMEGA6',
'SELENIUM',
'EPA',
'OMEGA6',
'MOS',
'OMEGA6',
'OMEGA3',
'OMEGA6',
'DUMMY',
'MICRO_ORGANISMS',
'MICRO_ORGANISMS',
'MICRO_ORGANISMS',
'OMEGA3',
'CHONDROITIN',
'CHONDROITIN',
'DHA',
'ENTEROCOCCUS_FAECIUM',
'LACTIC_ACID',
'METABOLIZABLE_ENERGY',
'OMEGA3',
'OMEGA6',
'MICRO_ORGANISMS',
'ASH',
'BACILLIUS',
'BACILLIUS',
'CALCIUM',
'CARBOHYDRATE',
'CHONDROITIN',
'PROTEIN',
'OMEGA3',
'OMEGA6',
'GLUCOSAMINE',
'MAGNESIUM',
'OMEGA3',
'OMEGA6',
'OMEGA3',
'ORGANIC_INGREDIENTS',
'BACILLIUS',
'CARBOHYDRATE',
'CHONDROITIN',
'COSAHEXAENOIC_ACID',
'GLUCOSAMINE',
'OMEGA3',
'OMEGA6',
'BACILLIUS',
'FIBER',
'PROTEIN',
'TAURINE',
'ISOFLAVONES',
'ARA',
'CARBOHYDRATE',
'OMEGA3',
'OMEGA6',
'PHOSPHOROUS',
'OMEGA3',
'OMEGA6',
'FAT',
'FIBER',
'ENZYMES',
'GLUCOSAMINE',
'MAGNESIUM',
'VITAMIN_C',
'VITAMIN_C',
'CARNITINE',
'MOISTURE',
'LINEOLEIC_ACID',
'LINEOLEIC_ACID',
'LACOBACILUUS_ACIDOPHILUS',
'MOISTURE',
'PHOSPHOROUS',
'VITAMIN_E',
'OMEGA3',
'VITAMIN_C',
'CARNITINE',
'DUMMY',
'CALCIUM',
'CARBOHYDRATE',
'FAT',
'PROTEIN',
'DUMMY',
'LINEOLEIC_ACID',
'LINEOLEIC_ACID',
'MOTHER’S_MILK',
'SELENIUM',
'VITAMIN_A',
'VITAMIN_E',
'VITAMIN_C',
'BONE',
'CALCIUM',
'CARBOHYDRATE',
'PROTEIN',
'GLUCOSAMINE',
'CARNITINE',
'MOISTURE',
'VITAMIN_E',
'ASH',
'CHONDROITIN',
'FIBER',
'FIBER',
'GLUCOSAMINE',
'CARNITINE',
'OMEGA3',
'PHOSPHOROUS',
'PHOSPHOROUS',
'TAURINE',
'AD_LIBITUM',
'FIBER',
'FOS',
'CARNITINE',
'FOS',
'ARGININE',
'METHIONINE',
'ORGAN MEAT',
'PHOSPHOROUS',
'PHOSPHOROUS',
'VITAMIN_B6',
'RIBOFLAVIN',
'TAURINE',
'VITAMIN_D',
'VITAMIN_E',
'ASH',
'FAT',
'OIL',
'DHA',
'EPA',
'IRON',
'MAGNESIUM',
'MANGANESE',
'PHOSPHOROUS',
'VITAMIN_A',
'VITAMIN_C',
'VITAMIN_D',
'VITAMIN_E',
'ZIN',
'ARGININE',
'CARNITINE',
'CHLORIDE',
'FAT',
'IRON',
'ASH',
'DUMMY',
'DHA'
]

# %%
list_ind2=[re.sub('[^A-Za-z0-9]+', ' ',x) for x in list_ind_csv]

# %%
#create indredient origin and tags reference dictionary
#export list of ingridient and tag each in excel and format the list 
#(e.g. put quotes around item)

ind_dict=dict(zip(list_ind2,list_tag))

# %%
ind_dict
# Out:
# {'ABSORBIC ACID': 'VITAMIN_C',
#  'ABSORBIC ACID ': 'VITAMIN_C',
#  'ABSORBIC ACID VITAMIN C ': 'VITAMIN_C',
#  'AD LIBITUM': 'AD_LIBITUM',
#  'ALPHA AMYLASE': 'OMEGA3',
#  'ALPHA LINOLENIC ACID': 'OMEGA3',
#  'ALPHA LINOLENIC ACID ALA ': 'OMEGA3',
#  'ALPHA LINOLENIC ACID AN OMEGA 3 FATTY ACID ': 'OMEGA3',
#  'ALPHA LINOLENIC ACID OMEGA 3 ': 'OMEGA3',
#  'ALPHA LINOLENIC ACID OMEGA 3 FATTY ACID ': 'OMEGA3',
#  'APPROXIMATE NUMBER OF 8 OZ CUPS PER DAY': 'DUMMY',
#  'ARACHIDONIC ACID': 'ARA',
#  'ARGININE': 'ARGININE',
#  'ASCORBIC ACID': 'VITAMIN_C',
#  'ASCORBIC ACID ': 'VITAMIN_C',
#  'ASCORBIC ACID SOURCE OF VITAMIN C ': 'VITAMIN_C',
#  'ASCORBIC ACID VITAMIN C': 'VITAMIN_C',
#  'ASCORBIC ACID VITAMIN C ': 'VITAMIN_C',
#  'ASCORBIC ACID VITAMINC ': 'VITAMIN_C',
#  'ASCORBIC ACID VITMAIN C ': 'VITAMIN_C',
#  'ASCORBIC ACIF VITAMIN C ': 'VITAMIN_C',
#  'ASCROBIC ACID VITAMIN C ': 'VITAMIN_C',
#  'ASH CONTENT': 'ASH',
#  'ASH MAX': 'ASH',
#  'ASH MAX 6 50 MAX': 'ASH',
#  'AVERAGE': 'DUMMY',
#  'BACILLIUS COAGULANS': 'BACILLIUS',
#  'BACILLUS COAGULANS': 'BACILLIUS',
#  'BACILLUS COAGULANS ': 'BACILLIUS',
#  'BACILLUS SUBTILIS': 'BACILLIUS',
#  'BETA CAROTENE': 'CARNITINE',
#  'BETA CAROTENE ': 'CARNITINE',
#  'BIFIDOBACTERIUM LONGUM': 'BIFIDOBACTERIUM',
#  'BIFIDOBACTERIUM THERMOPHILUM': 'BIFIDOBACTERIUM',
#  'BONE CONTENT': 'BONE',
#  'BREEDING MARES AND STALLIONS': 'DUMMY',
#  'CA TO P RATIO': 'DUMMY',
#  'CALCIUM CA ': 'CALCIUM',
#  'CALCIUM MIN ': 'CALCIUM',
#  'CALCIUM PHOSPHOROUS': 'CALCIUM',
#  'CALCIUM PHOSPHOROUS RATIO': 'CALCIUM',
#  'CALCIUM TO PHOSPHOROUS RATIO': 'CALCIUM',
#  'CALIUM PHOSPHOROUS RATIO': 'CALCIUM',
#  'CARBOHYDRATE': 'CARBOHYDRATE',
#  'CARBOHYDRATE NFE': 'CARBOHYDRATE',
#  'CARBOHYDRATES': 'CARBOHYDRATE',
#  'CARBOHYDRATES NFE ': 'CARBOHYDRATE',
#  'CAROTENE': 'CARNITINE',
#  'CHLORIDE': 'CHLORIDE',
#  'CHODROITIN SULFATE': 'CHONDROITIN',
#  'CHONDROITIN': 'CHONDROITIN',
#  'CHONDROITIN SULFATE': 'CHONDROITIN',
#  'CHONDROITIN SULFATE ': 'CHONDROITIN',
#  'CHONDROITIN SULFATE MIN ': 'CHONDROITIN',
#  'CHONDROITIN SULFATE NATURALLY OCCURRING ': 'CHONDROITIN',
#  'CHONDROITIN SULPHATE': 'CHONDROITIN',
#  'COSAHEXAENOIC ACID': 'COSAHEXAENOIC_ACID',
#  'CRUDE ASH': 'ASH',
#  'CRUDE FAT': 'FAT',
#  'CRUDE FAT MIN': 'FAT',
#  'CRUDE FAT MIN ': 'FAT',
#  'CRUDE FIBER': 'FIBER',
#  'CRUDE FIBER MAX': 'FIBER',
#  'CRUDE FIBER MAX ': 'FIBER',
#  'CRUDE FIBRE': 'FIBER',
#  'CRUDE MOISTURE': 'MOISTURE',
#  'CRUDE OIL': 'OIL',
#  'CRUDE PROTEIN': 'PROTEIN',
#  'CRUDE PROTEIN MIN': 'PROTEIN',
#  'CRUDE PROTEIN MIN ': 'PROTEIN',
#  'CRUDEFAT': 'FAT',
#  'CRUDEFIBER': 'FIBER',
#  'CRUDEPROTEIN': 'PROTEIN',
#  'DHA DOCOSAHEXAENOIC ACID ': 'DHA',
#  'DHA DOCOSOHEXAENOIC ACID ': 'DHA',
#  'DHA EPA': 'DHA',
#  'DHA MIN': 'DHA',
#  'DOCOSAHEXAENOIC ACID': 'DHA',
#  'DOCOSAHEXAENOIC ACID DHA ': 'DHA',
#  'DOCOSOHEXAENOIC ACID DHA ': 'DHA',
#  'DOCOSOHEXAENOICACID DHA ': 'DHA',
#  'EICOSAPENTAENOIC ACID': 'EPA',
#  'EICOSAPENTAENOIC ACID EPA': 'EPA',
#  'EICOSAPENTAENOIC ACID EPA ': 'EPA',
#  'ENCAPSULATED PROBIOTICS': 'ENCAPSULATED_PROBIOTICS',
#  'ENTEROCOCCUS FAECIUM': 'ENTEROCOCCUS_FAECIUM',
#  'ENZYMES LIPASE': 'ENZYMES',
#  'EPA DHA': 'EPA',
#  'EPA EICOSAPENTAENOIC ACID ': 'EPA',
#  'EPA EICOSAPENTAENOIC ACID DHA DOCOSAHEXAENOIC ACID ': 'EPA',
#  'EVERY 10 LBS': 'DUMMY',
#  'FATTY ACIDS OMEGA 3': 'OMEGA3',
#  'FATTY ACIDS OMEGA 6': 'OMEGA6',
#  'FOLIC ACID': 'FOS',
#  'FRUCTOOLIGOSACCHARIDES': 'FOS',
#  'FUCTOOLIGOSACCHARIDES FOS ': 'FOS',
#  'GESTATING 1 2 ': 'GLUCOSAMINE',
#  'GESTATING 5 8 ': 'GLUCOSAMINE',
#  'GLUCOSAMINE': 'GLUCOSAMINE',
#  'GLUCOSAMINE ': 'GLUCOSAMINE',
#  'GLUCOSAMINE HCL': 'GLUCOSAMINE',
#  'GLUCOSAMINE HYDROCHLORIDE': 'GLUCOSAMINE',
#  'GLUCOSAMINE HYDROCHLORIDE ': 'GLUCOSAMINE',
#  'GLUCOSAMINE MIN ': 'GLUCOSAMINE',
#  'GLUCOSAMINE NATURALLY OCCURRING ': 'GLUCOSAMINE',
#  'GLUCOSAMINE SULFATE': 'GLUCOSAMINE',
#  'I CARNITIE': 'CARNITINE',
#  'INULIN FOS': 'FOS',
#  'IRON 225': 'IRON',
#  'IRON FE ': 'IRON',
#  'L ARGININE': 'ARGININE',
#  'L ASCORBYL 2 POLYPHOSPHATE SOURCE OF VITAMIN C ': 'VITAMIN_C',
#  'L CARNITINE': 'CARNITINE',
#  'L CARNITINE ': 'CARNITINE',
#  'LACOBACILUUS ACIDOPHILUS': 'LACOBACILUUS_ACIDOPHILUS',
#  'LACTIC ACID BACTERIA': 'LACTIC_ACID',
#  'LACTIC ACID MICROORGANISMS': 'LACTIC_ACID',
#  'LACTOBACILLUS ACIDOPHILUS': 'LACOBACILUUS_ACIDOPHILUS',
#  'LINEOLEIC ACID': 'LINEOLEIC_ACID',
#  'LINOLEIC ACID': 'LINEOLEIC_ACID',
#  'LINOLEIC ACID AN OMEGA 6 FATTY ACID ': 'OMEGA6',
#  'LINOLEIC ACID OMEGA 6': 'OMEGA6',
#  'LINOLEIC ACID OMEGA 6 ': 'OMEGA6',
#  'LINOLEIC ACID OMEGA 6 FATTY ACID ': 'OMEGA6',
#  'LINOLEIC ACID OMEGA 6 FATTY ACIDS ': 'OMEGA6',
#  'LINOLENIC ACID': 'LINEOLEIC_ACID',
#  'LINOLENIC ACID OMEGA 3': 'OMEGA3',
#  'LINOLENIC ACID OMEGA 3 ': 'OMEGA3',
#  'LINOLIEC ACID': 'LINEOLEIC_ACID',
#  'MAGNESIUM': 'MAGNESIUM',
#  'MAGNESIUM 0 14 MAX': 'MAGNESIUM',
#  'MAGNESIUM MAX ': 'MAGNESIUM',
#  'MANGANESE': 'MANGANESE',
#  'MANNANOLIGOACCHARIDES': 'MOS',
#  'MANNANOLIGOSACCHARIDES MOS ': 'MOS',
#  'METABOLIZABLE ENERGY': 'METABOLIZABLE_ENERGY',
#  'METHIONINE': 'METHIONINE',
#  'MICROORGANISMS': 'LACOBACILUUS_ACIDOPHILUS',
#  'MICROORGANISMS LACTOBACILLUS ACIDOPHILUS': 'LACOBACILUUS_ACIDOPHILUS',
#  'MOISTEN FEED FREQUENTLY': 'DUMMY',
#  'MOISTURE MAX': 'MOISTURE',
#  'MOISTURE MAX ': 'MOISTURE',
#  'MOTHER S MILK': 'MOTHER’S_MILK',
#  'OMEGA 3 DHA': 'OMEGA3',
#  'OMEGA 3 FATTY ACID': 'OMEGA3',
#  'OMEGA 3 FATTY ACID ': 'OMEGA3',
#  'OMEGA 3 FATTY ACIDS': 'OMEGA3',
#  'OMEGA 3 FATTY ACIDS ': 'OMEGA3',
#  'OMEGA 3 FATTY ACIDS MIN': 'OMEGA3',
#  'OMEGA 3 FATTY ACIDS MIN ': 'OMEGA3',
#  'OMEGA 3 LINOLENIC ACID ': 'OMEGA3',
#  'OMEGA 6 FATTY ACID': 'OMEGA6',
#  'OMEGA 6 FATTY ACIDS': 'OMEGA6',
#  'OMEGA 6 FATTY ACIDS ': 'OMEGA6',
#  'OMEGA 6 FATTY ACIDS MIN': 'OMEGA6',
#  'OMEGA 6 FATTY ACIDS MIN ': 'OMEGA6',
#  'OMEGA 6 FATTY ACIDS TOTAL': 'OMEGA6',
#  'OMEGA 6 LINOLEIC ACID ': 'OMEGA6',
#  'OMEGA3FATTYACIDS': 'OMEGA3',
#  'OMEGA6FATTYACIDS': 'OMEGA6',
#  'ORGAN MEAT': 'ORGAN MEAT',
#  'ORGANIC INGREDIENTS': 'ORGANIC_INGREDIENTS',
#  'PHOSPHEROUS': 'PHOSPHOROUS',
#  'PHOSPHOROUS': 'PHOSPHOROUS',
#  'PHOSPHORUS': 'PHOSPHOROUS',
#  'PHOSPHORUS MIN ': 'PHOSPHOROUS',
#  'PHOSPHORUS P ': 'PHOSPHOROUS',
#  'PHOSPOROUS': 'PHOSPHOROUS',
#  'PHOSPORUS': 'PHOSPHOROUS',
#  'PRODUCE SUPPLEMENTS': 'DUMMY',
#  'PYRIDOXINE': 'VITAMIN_B6',
#  'PYRIDOXINE VITAMIN B6 ': 'VITAMIN_B6',
#  'RIBOFLAVIN': 'RIBOFLAVIN',
#  'SELENIUM 0 35 MG KG MIN': 'SELENIUM',
#  'SELENIUM 45 MG KG MIN': 'SELENIUM',
#  'SELENIUM SE ': 'SELENIUM',
#  'TAURINE 0 05 MIN': 'TAURINE',
#  'TAURINE DM': 'TAURINE',
#  'TAURINE MIN': 'TAURINE',
#  'TOTAL BACILLUS ORGANISMS': 'BACILLIUS',
#  'TOTAL ISOFLAVONES': 'ISOFLAVONES',
#  'TOTAL LACTIC ACID MICROORGANISMS': 'LACTIC_ACID',
#  'TOTAL LACTIC ACID MICROORGANISMS ': 'LACTIC_ACID',
#  'TOTAL MICRO ORGANISMS': 'MICRO_ORGANISMS',
#  'TOTAL MICROORGANISMS': 'MICRO_ORGANISMS',
#  'TOTAL MICROORGANISMS ': 'MICRO_ORGANISMS',
#  'TOTAL MICROORGANISMS LACTOBACILLUS ACIDOPHILUS': 'MICRO_ORGANISMS',
#  'TOTAL MICROORGANSISMS': 'MICRO_ORGANISMS',
#  'TOTAL OMEGA 3 FA': 'OMEGA3',
#  'TOTAL OMEGA 6 FA': 'OMEGA6',
#  'VITAMIN A': 'VITAMIN_A',
#  'VITAMIN A MIN': 'VITAMIN_A',
#  'VITAMIN A RETINYL ACETATE ': 'VITAMIN_A',
#  'VITAMIN C': 'VITAMIN_C',
#  'VITAMIN D': 'VITAMIN_D',
#  'VITAMIN D CHOLECALCIFEROL ': 'VITAMIN_D',
#  'VITAMIN D3': 'VITAMIN_D',
#  'VITAMIN E': 'VITAMIN_E',
#  'VITAMIN E 35': 'VITAMIN_E',
#  'VITAMIN E DL ASLPHA TOCOPHERYL ACETATE ': 'VITAMIN_E',
#  'VITAMIN E MIN': 'VITAMIN_E',
#  'VITAMIN E MIN ': 'VITAMIN_E',
#  'VITAMINE E': 'VITAMIN_E',
#  'ZINC ZN ': 'ZIN'}

# %%
def result(ele):
    pattern = re.compile(r'\b(' + '|'.join(ind_dict.keys()) + r')\b')
    return pattern.sub(lambda x: ind_dict[x.group()], ele)  
#function to translate ingredient to standard ingredient tags

# %%
temp_ind_list= [re.sub('[^A-Za-z0-9,\.%]+', ' ',x) for x in df['ingredient'].tolist()]

# %%
df['ind_tag_list']=[result(x.upper()) for x in temp_ind_list]  
#create the column for translated list of ingredient tags

# %%
df['ind_tag_list'].iloc[0]
# Out:
# 'PROTEIN,32.0% MIN,FAT,18.0% MIN,FIBER,4.0% MAX,MOISTURE,10.0% MAX,ZINC,150 MG KG MIN,SELENIUM,0.35 MG KG MIN,VITAMIN_E,150 IU KG MIN,OMEGA6,2.8% MIN,OMEGA3,0.3% MIN,MICRO_ORGANISMS,1,000,000 CFU LB MIN'

# %%
#convert ingredient tag column in df to dictionary
def split_ind(x):
    if type(x)==type('') and x!='':
        return  [re.sub('[^A-Za-z0-9,\.%]+', ' ',element).strip() for element in re.split('MIN,|MAX,',x)]
    else:
        return ['DUMMY,DUMMY']
    
    
def split_dic(x):
    return list(map(lambda x:  tuple( re.sub('[^A-Za-z0-9\.%]+', '',x).strip() for x in x.strip().rsplit(',',1))\
                    if len(tuple(x.strip().rsplit(',',1)))==2 else ('DUMMY','DUMMY') ,x))

temp_list=df['ind_tag_list'].map(lambda x: split_ind(x))
# #type(temp_list)

# dict(split_dic(temp_list.iloc[1]))
for element in temp_list[:500]:
    try:
        dict(split_dic(element))
    except:
        print(split_dic(element))
        
#convert tag list column to ingredient dictionaries, the preprocessing for split columns
df['ind_dict']=[dict(split_dic(element)) for element in temp_list]

# %%
pd.DataFrame(df['ind_dict'].tolist()).to_csv('~/Desktop/temp.csv')  # test dictionary

# %%
ind_col=pd.DataFrame(df['ind_dict'].tolist())
df['product_id']=np.arange(len(df['ind_dict'])) #create index column

# %%
#choose top 15 ingredients 
d=dict(ind_col.count(axis=0))
from collections import OrderedDict
od = sorted(d.items(), key=lambda x:x[1], reverse=True)
cols=list(OrderedDict(od[:26]).keys())
cols
# Out:
# ['PROTEIN',
#  'FAT',
#  'FIBER',
#  'MOISTURE',
#  'TAURINE',
#  'ASH',
#  'OMEGA6',
#  'OMEGA3',
#  'CALCIUM',
#  'DUMMY',
#  'PHOSPHOROUS',
#  'VITAMINE',
#  'MAGNESIUM',
#  'VITAMINC',
#  'GLUCOSAMINE',
#  'DHADHA',
#  'CHONDROITIN',
#  'ZINC',
#  'CARNITINE',
#  'LINEOLEICACID',
#  'SELENIUM',
#  'EPA',
#  'DHA',
#  'SODIUM',
#  'VITAMINA10',
#  'CARBOHYDRATE']

# %%
#pd.DataFrame(df['ind_dict'].iloc[1:3].tolist())
# Out:
# {'FAT': '18.0%',
#  'FIBER': '4.0%',
#  'MICROORGANISMS1000': '000CFULBMIN',
#  'MOISTURE': '10.0%',
#  'OMEGA3': '0.3%',
#  'OMEGA6': '2.8%',
#  'PROTEIN': '32.0%',
#  'SELENIUM': '0.35MGKG',
#  'VITAMINE': '150IUKG',
#  'ZINC': '150MGKG'}

# %%
import numpy as np
import pandas as pd
objs = [df, pd.DataFrame(df['ind_dict'].tolist())[cols]
       ]
#test=pd.DataFrame(df['ind_dict'].tolist())[cols]
df2=pd.concat(objs, axis=1).drop('ind_dict', axis=1)

# %%
#convert ingredient into digit
def digit_obj(x):
    try:        
        if type(x)==type('') and x!='':
            temp=re.sub('[^0-9\.]+', '',x).strip()
            if temp=='':
                return 0.0
            else:
                return float(temp)
        else:
            return 0
    except:
        float(x.split('.')[0])

df2[['PROTEIN',
       'FAT', 'FIBER', 'MOISTURE', 'TAURINE', 'ASH', 'OMEGA6', 'OMEGA3',
       'CALCIUM', 'PHOSPHOROUS', 'VITAMINE', 'MAGNESIUM', 'VITAMINC',
       'GLUCOSAMINE', 'DHADHA', 'CHONDROITIN', 'ZINC', 'CARNITINE',
       'LINEOLEICACID', 'SELENIUM', 'EPA', 'DHA', 'SODIUM', 'VITAMINA10',
       'CARBOHYDRATE']] = df2[['PROTEIN',
       'FAT', 'FIBER', 'MOISTURE', 'TAURINE', 'ASH', 'OMEGA6', 'OMEGA3',
       'CALCIUM', 'PHOSPHOROUS', 'VITAMINE', 'MAGNESIUM', 'VITAMINC',
       'GLUCOSAMINE', 'DHADHA', 'CHONDROITIN', 'ZINC', 'CARNITINE',
       'LINEOLEICACID', 'SELENIUM', 'EPA', 'DHA', 'SODIUM', 'VITAMINA10',
       'CARBOHYDRATE']].applymap(digit_obj)  #trim data

# %%
import numpy as np
import matplotlib.pyplot as plt

from time import time
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
#import sklearn

# %%
np.all(np.isnan(data))
# Out:
# False

# %%
data=df2[['PROTEIN',
       'FAT', 'FIBER', 'MOISTURE', 'TAURINE', 'ASH', 'OMEGA6', 'OMEGA3',
       'CALCIUM', 'PHOSPHOROUS', 'VITAMINE', 'MAGNESIUM', 'VITAMINC',
       'GLUCOSAMINE', 'DHADHA', 'CHONDROITIN', 'ZINC', 'CARNITINE',
       'LINEOLEICACID', 'SELENIUM', 'EPA', 'DHA', 'SODIUM', 'VITAMINA10',
       'CARBOHYDRATE']]


bench_k_means(KMeans(init='k-means++', n_init=10),
              name="k-means++", data=data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1438-c51f449b7898> in <module>()
#       8
#       9 bench_k_means(KMeans(init='k-means++', n_init=10),
# ---> 10               name="k-means++", data=data)
#
# <ipython-input-1315-c605f758cb4c> in bench_k_means(estimator, name, data)
#      13 def bench_k_means(estimator, name, data):
#      14     t0 = time()
# ---> 15     estimator.fit(data)
#      16     print('% 9s   %.2fs    %i   %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
#      17           % (name, (time() - t0), estimator.inertia_,
#
# /Users/ssss/anaconda/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y)
#     878         """
#     879         random_state = check_random_state(self.random_state)
# --> 880         X = self._check_fit_data(X)
#     881
#     882         self.cluster_centers_, self.labels_, self.inertia_, self.n_iter_ = \
#
# /Users/ssss/anaconda/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in _check_fit_data(self, X)
#     852     def _check_fit_data(self, X):
#     853         """Verify that the number of samples given is larger than k"""
# --> 854         X = check_array(X, accept_sparse='csr', dtype=[np.float64, np.float32])
#     855         if X.shape[0] < self.n_clusters:
#     856             raise ValueError("n_samples=%d should be >= n_clusters=%d" % (
#
# /Users/ssss/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /Users/ssss/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# Out:
# array([[ 0.        , -0.33501649, -0.04308102, ..., -1.14664746,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  0.54856067,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  1.56568555,
#          1.6951369 , -0.19600752],
#        ...,
#        [ 0.        , -0.33501649, -0.88456568, ..., -0.12952258,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -0.67419451, ...,  0.8876023 ,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649,  1.00877481, ...,  0.8876023 ,
#         -0.26113572, -0.19600752]])
